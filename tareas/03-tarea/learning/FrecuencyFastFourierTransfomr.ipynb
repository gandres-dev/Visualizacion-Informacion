# %% [markdown]
# # Frequency and the Fast Fourier Transform

# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft, fftshift

#plt.style.use('seaborn')
plt.style.use('seaborn-whitegrid') #classic

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
f = 10      # Frecuancia, ciclos por segundos o 10 Hertz
f_s = 100   # Sampling rate, Numoer de mediciones por segundo

t = np.linspace(0, 2, 2 * f_s, endpoint=False)
x = np.sin(f * 2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, x)
ax.set_xlabel('Time[s]')
ax.set_ylabel('Signal amplitude')
# Out:
# Text(0, 0.5, 'Signal amplitude')

# %%
from scipy.fft import fft, ifft, fftfreq

X = fft(x)
freqs = fftfreq(len(x)) * f_s

fig, ax = plt.subplots()

ax.stem(freqs, np.abs(X))
ax.set_xlabel('Frequency in Hertz [Hz]')
ax.set_ylabel('Frequency Domain (Spectrum) Magnitude')
ax.set_xlim(-f_s / 2, f_s / 2)
ax.set_ylim(-5, 110)
# Out:
# (-5.0, 110.0)

# %%
from scipy.fft import fft, ifft, fftfreq, fftshift

X = fft(y)
freqs = fftfreq(len(y)) * N

fig, ax = plt.subplots()

ax.stem(freqs, np.abs(X))
ax.set_xlabel('Frequency in Hertz [Hz]')
ax.set_ylabel('Frequency Domain (Spectrum) Magnitude')
ax.set_xlim(-N / 2, N / 2)
ax.set_ylim(-5, 110)

# %% [markdown]
# ## References
#
# - https://www.oreilly.com/library/view/elegant-scipy/9781491922927/ch04.html
#
# ---

# %%
N = 512
T = 1.0 / N
L = 1024
t = np.linspace(0, L*T, N)
s = 2 * np.sin(2 * np.pi * t) + np.sin(2 * np.pi * 12.5 * t) + 1.5 * np.sin(2 * np.pi* 20 * t) + 0.5 * np.sin(2 * np.pi * 155 * t)
plt.plot(t, s)

# %%
# Espectro de frecuencia
Y = fft(s)
plt.plot(abs(Y))

# %%
# Vemos que tiene simetria par
plt.plot(fftshift(abs(Y)))

# %%
# Espectro de fase
plt.plot(Y.imag)

# %%
# Tiene simetria impar, 
# Sacando la simetria ttf
plt.plot(fftshift(Y.imag))

# %% [markdown]
# # Referencias
#
# - https://youtu.be/SrFkYY_VmNE
# - https://youtu.be/syiOiOQPktI

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import pi

N = 512
T = 1.0 / N
L = 1024
t = np.linspace(0, L*T, N)
s = 2 * np.sin(2 * np.pi * t) + np.sin(2 * np.pi * 12.5 * t) + 1.5 * np.sin(2 * np.pi* 20 * t) + 0.5 * np.sin(2 * np.pi * 155 * t)
plt.plot(t, s)

# Espectro de frecuencia
Y = fft(s)
plt.plot(abs(Y))

# Vemos que tiene simetria par
plt.plot(fftshift(abs(Y)))

# Espectro de fase
plt.plot(Y.imag)

# Tiene simetria impar, 
# Sacando la simetria ttf
plt.plot(fftshift(Y.imag))

# Graficando el espectro de Fase (Parte imaginaria)
plt.plot(abs(fftshift(yt.imag)))

# %% [markdown]
# ## Otras referencias
#
# - https://conceptosclaros.com/transformada-de-fourier/
# - https://betterexplained.com/articles/an-interactive-guide-to-the-fourier-transform/
# - https://www.ub.edu/journalofexperimentalphonetics/pdf-articles/EFE-X-JBernal_PGomez_JBobadilla-FFT_una_vision_practica_herramienta_para_el_analisis_espectral_de_la_voz.pdf

# %% [markdown]
# # Referencia
# - https://appdividend.com/2022/01/19/numpy-fft/
# - https://www.nti-audio.com/es/servicio/conocimientos/transformacion-rapida-de-fourier-fft#:~:text=La%20%22Transformaci%C3%B3n%20r%C3%A1pida%20de%20Fourier,proporciona%20informaci%C3%B3n%20sobre%20su%20composici%C3%B3n.
